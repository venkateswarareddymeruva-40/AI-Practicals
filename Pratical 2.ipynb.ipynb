# %%
from collections import deque

# Treasure map (Graph)
treasure_map = {
    'Start': ['A', 'B'],
    'A': ['C', 'D'],
    'B': ['E'],
    'C': [],
    'D': ['Treasure'],
    'E': [],
    'Treasure': []
}

def bfs(graph, start, goal):
    queue = deque([[start]])
    visited = set()

    while queue:
        path = queue.popleft()
        node = path[-1]

        if node == goal:
            return path

        if node not in visited:
            visited.add(node)

            for neighbor in graph[node]:
                new_path = list(path)
                new_path.append(neighbor)
                queue.append(new_path)

    return None

path = bfs(treasure_map, "Start", "Treasure")

print("Treasure Found!")
print("Shortest Path:", " -> ".join(path))
# Out:
# Treasure Found!
# Shortest Path: Start -> A -> D -> Treasure

# %%
map_rooms = {
    "A": ["B", "C"],
    "B": ["D"],
    "C": ["D"],
    "D": ["G"],
    "G": []
}

print("Our map:")
print("          A (Start)")
print("         / \\")
print("        B   C")
print("         \\ /")
print("          D")
print("          |")
print("          G (Treasure 💎)")
print()

print("Doors from each room:", map_rooms)
# Out:
# Our map:
#           A (Start)
#          / \
#         B   C
#          \ /
#           D
#           |
#           G (Treasure 💎)
#
# Doors from each room: {'A': ['B', 'C'], 'B': ['D'], 'C': ['D'], 'D': ['G'], 'G': []}

# %%
def bfs(start, goal):
    to_do = [start]      # rooms waiting to be checked
    visited = []         # rooms we have already checked
    order = []           # the order we checked rooms

    while to_do:
        # Take from the FRONT of the list
        room = to_do.pop(0)

        if room in visited:
            continue

        visited.append(room)
        order.append(room)

        if room == goal:
            return order      # found the treasure!

        for nxt in map_rooms[room]:
            to_do.append(nxt)

    return order


order = bfs("A", "G")
print("BFS checked the rooms in this order:", order)
print("Number of rooms BFS checked:", len(order))
# Out:
# BFS checked the rooms in this order: ['A', 'B', 'C', 'D', 'G']
# Number of rooms BFS checked: 5

# %%
door_cost = {
    ("A", "B"): 1,
    ("A", "C"): 1,
    ("B", "D"): 1,
    ("C", "D"): 5,
    ("D", "G"): 1,
}


def path_cost(path):
    total = 0
    for i in range(len(path) - 1):
        door = (path[i], path[i + 1])
        total = total + door_cost[door]
    return total

path1 = ["A", "B", "D", "G"]
path2 = ["A", "C", "D", "G"]

print("Path 1 A -> B -> D -> G costs:", path_cost(path1))
print("Path 2 A -> C -> D -> G costs:", path_cost(path2))

cost1 = path_cost(path1)
cost2 = path_cost(path2)


if cost1 < cost2:
    best_path = path1
    best_cost = cost1
else:
    best_path = path2
    best_cost = cost2

print("Path 1 cost:", cost1)
print("Path 2 cost:", cost2)
print("The cheapest path is", best_path, "with cost", best_cost, )

# Define the map_rooms for the DFS function
map_rooms = {
    "A": ["B", "C"],   # from A you can go to B or C
    "B": ["D"],        # from B you can go to D
    "C": ["D"],        # from C you can go to D
    "D": ["G"],        # from D you can go to G
    "G": []            # G is the treasure! No need to go further.
}

# Define the DFS function to resolve the NameError
def dfs(start, goal):
    stack = [start]  # Use a list as a stack (LIFO)
    visited = set()  # Keep track of visited nodes
    order = []       # Record the order of visited nodes

    while stack:
        room = stack.pop() # Get the last added element

        if room in visited:
            continue

        visited.add(room)
        order.append(room)

        if room == goal:
            return order  # Goal reached, return the path

        # Add neighbors to the stack. Reverse the neighbors list to explore
        # the first neighbor in the list first (when popping from the stack).
        for nxt in reversed(map_rooms[room]):
            if nxt not in visited:
                stack.append(nxt)
    return order # Return the order if goal is not found

bfs_order = dfs("A", "G")
dfs_order = dfs("A", "G")
# Out:
# Path 1 A -> B -> D -> G costs: 3
# Path 2 A -> C -> D -> G costs: 7
# Path 1 cost: 3
# Path 2 cost: 7
# The cheapest path is ['A', 'B', 'D', 'G'] with cost 3

# %%
door_cost = {
    ("A", "B"): 1,
    ("A", "C"): 1,
    ("B", "D"): 1,
    ("C", "D"): 5,
    ("D", "G"): 1,
}


def path_cost(path):
    total = 0
    for i in range(len(path) - 1):
        door = (path[i], path[i + 1])
        total = total + door_cost[door]
    return total

path1 = ["A", "B", "D", "G"]
path2 = ["A", "C", "D", "G"]

print("Path 1 A -> B -> D -> G costs:", path_cost(path1))
print("Path 2 A -> C -> D -> G costs:", path_cost(path2))

cost1 = path_cost(path1)
cost2 = path_cost(path2)


if cost1 < cost2:
    best_path = path1
    best_cost = cost1
else:
    best_path = path2
    best_cost = cost2

print("Path 1 cost:", cost1)
print("Path 2 cost:", cost2)
print("The cheapest path is", best_path, "with cost", best_cost, )

# Define the map_rooms for the DFS function
map_rooms = {
    "A": ["B", "C"],   # from A you can go to B or C
    "B": ["D"],        # from B you can go to D
    "C": ["D"],        # from C you can go to D
    "D": ["G"],        # from D you can go to G
    "G": []            # G is the treasure! No need to go further.
}

# Define the DFS function to resolve the NameError
def dfs(start, goal):
    stack = [start]  # Use a list as a stack (LIFO)
    visited = set()  # Keep track of visited nodes
    order = []       # Record the order of visited nodes

    while stack:
        room = stack.pop() # Get the last added element

        if room in visited:
            continue

        visited.add(room)
        order.append(room)

        if room == goal:
            return order  # Goal reached, return the path

        # Add neighbors to the stack. Reverse the neighbors list to explore
        # the first neighbor in the list first (when popping from the stack).
        for nxt in reversed(map_rooms[room]):
            if nxt not in visited:
                stack.append(nxt)
    return order # Return the order if goal is not found

bfs_order = dfs("A", "G")
dfs_order = dfs("A", "G")
# Out:
# Path 1 A -> B -> D -> G costs: 3
# Path 2 A -> C -> D -> G costs: 7
# Path 1 cost: 3
# Path 2 cost: 7
# The cheapest path is ['A', 'B', 'D', 'G'] with cost 3
